# %% [markdown]
# # 중구 - 명동 데이터 전처리 (업종별)

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy.stats import pearsonr
#환경 설정
plt.rcdefaults()
plt.rcParams["font.family"] = 'Haansoft Dotum'
plt.rcParams['axes.unicode_minus'] = False
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 1. 데이터 불러오기
# ### (1) 업종별 점포 데이터

# %%
path = 'C:/Users/Admin/Desktop/OSSP/data/서울시_우리마을가게_상권분석서비스(상권-점포)_'

# %%
# 2020년 = service_info_2020, 
# 2019년 = service_info_2019, 
# .... 
# 2015년 = service_info_2015

for i in range(2015, 2021):
    globals()['service_info_{}'.format(i)] = pd.read_csv(path + str(i) + '.csv', encoding = 'cp949')

# %%
# 확인

service_info_2020.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300042
# 2     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300041
# 3     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300040
# 4     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300038
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0      전자상거래업     8           8     0        0     0        0           0
# 1         주유소     1           1     0        0     0        0           0
# 2         예술품     9           9     0        0     0        0           0
# 3    재생용품 판매점     0           0     0        0     0        0           0
# 4       자동차부품    10          10     0        0     0        0           0

# %% [markdown]
# ### (2) 업종별 추정매출 데이터

# %%
path = 'C:/Users/Admin/Desktop/OSSP/data/서울시 우리마을가게 상권분석서비스(상권-추정매출)_'

# %%
# 2020년 = service_sales_2020, 
# 2019년 = service_sales_2019, 
# .... 
# 2015년 = service_sales_2015

for i in range(2015, 2021):
    globals()['service_sales_{}'.format(i)] = pd.read_csv(path + str(i) + '.csv', encoding = 'cp949')

# %%
# 확인

service_sales_2020.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 2     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 3     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# 4     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300027
#
#   서비스_업종_코드_명     당월_매출_금액  당월_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  \
# 0      전자상거래업      6415600       169  ...                0        63
# 1        가전제품   1853749205      8319  ...              132      4331
# 2          가구  10400909742      5270  ...               35      2458
# 3          화초    807257363     28506  ...              580      9007
# 4        섬유제품   1410497003     41063  ...             1445      8135
#
#    여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
# 0       106             0            10           139            10
# 1      3363            66          2146          2181          1234
# 2      2812             0             0           245          1441
# 3     18931           232         10926         10020          3876
# 4     32928          1478         20434          8248          5427
#
#    연령대_50_매출_건수  연령대_60_이상_매출_건수  점포수
# 0             5                5    8
# 1          1062             1003    8
# 2          1722             1862    5
# 3          2101              781    6
# 4          4241             1235    6
#
# [5 rows x 80 columns]

# %%
# 2015 ~ 2020 추정매출, 폐업률 수직 통합

total_service_info = pd.DataFrame()
total_service_sales = pd.DataFrame()

# 점포 데이터 통합 (2015 ~ 2020)
for i in range (2015, 2021):
    total_service_info = total_service_info.append(globals()['service_info_{}'.format(i)], ignore_index = True)

# 불필요한 column 제거
total_service_info = total_service_info.drop(['상권_구분_코드', '상권_구분_코드_명'], axis=1)

# 추정매출 데이터 통합 (2015 ~ 2020)
for i in range (2015, 2021):
    total_service_sales = total_service_sales.append(globals()['service_sales_{}'.format(i)], ignore_index = True)

# 불필요한 column 제거
total_service_sales = total_service_sales.drop(['상권_구분_코드', '상권_구분_코드_명'], axis=1)

# %%
# 결과 확인
# 통합 점포 데이터

total_service_info.head()
# Out:
#    기준_년_코드  기준_분기_코드    상권_코드       상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  \
# 0     2015         1  1001490       길동복조리시장  CS300011        일반의류    33
# 1     2015         1  1001046  서울 관악구 신림역_4  CS300001        슈퍼마켓    18
# 2     2015         1  1000609        개봉로11길  CS100001       한식음식점     9
# 3     2015         1  1000910       도산대로81길  CS100004       양식음식점     9
# 4     2015         1  1000862        방배로18길  CS100002       중식음식점     1
#
#    유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0          33     0        0     3        1           0
# 1          18     0        0     0        0           0
# 2           9     0        0     0        0           0
# 3           9    22        2    33        3           0
# 4           2     0        0     0        0           1

# %%
# 결측치 확인

total_service_info.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 상권_코드          0
# 상권_코드_명        0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 유사_업종_점포_수     0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# dtype: int64

# %%
total_service_sales.head()

# %%
# 결측치 확인

total_service_sales.isnull().sum()
# Out:
# 기준_년_코드            0
# 기준_분기_코드           0
# 상권_코드              0
# 상권_코드_명            0
# 서비스_업종_코드          0
#                   ..
# 연령대_30_매출_건수       0
# 연령대_40_매출_건수       0
# 연령대_50_매출_건수       0
# 연령대_60_이상_매출_건수    0
# 점포수                0
# Length: 78, dtype: int64

# %%
# 공통되는 column 찾기

c_info = set(total_service_info.columns)
c_sales = set(total_service_sales.columns)
c_same = list(set.intersection(c_info, c_sales))

c_same
# Out:
# ['상권_코드', '기준_년_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명', '기준_분기_코드']

# %%
# total_df = 통합 점포 데이터 + 통합 추정매출 데이터

total_df = pd.merge(total_service_info, total_service_sales, how = 'left', on = c_same)

# %%
# 결과 확인
# 전체 통합 데이터

total_df.head()
# Out:
#    기준_년_코드  기준_분기_코드    상권_코드       상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  \
# 0     2015         1  1001490       길동복조리시장  CS300011        일반의류    33
# 1     2015         1  1001046  서울 관악구 신림역_4  CS300001        슈퍼마켓    18
# 2     2015         1  1000609        개봉로11길  CS100001       한식음식점     9
# 3     2015         1  1000910       도산대로81길  CS100004       양식음식점     9
# 4     2015         1  1000862        방배로18길  CS100002       중식음식점     1
#
#    유사_업종_점포_수  개업_율  개업_점포_수  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 0          33     0        0  ...           643.00   4389.00  11072.00
# 1          18     0        0  ...         48014.00  79772.00 108601.00
# 2           9     0        0  ...           664.00   1620.00    951.00
# 3           9    22        2  ...          1908.00   4735.00   6426.00
# 4           2     0        0  ...            75.00   1726.00    892.00
#
#    연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# 0         97.00       1205.00       2267.00       4759.00       4584.00
# 1       1293.00      68332.00      55144.00      26564.00      23568.00
# 2          7.00        199.00        509.00        785.00        662.00
# 3         81.00       3347.00       4750.00       1784.00        929.00
# 4         16.00        509.00       1021.00        731.00        220.00
#
#    연령대_60_이상_매출_건수   점포수
# 0          2549.00 33.00
# 1         13473.00 18.00
# 2           407.00  9.00
# 3           276.00 10.00
# 4           121.00  2.00
#
# [5 rows x 85 columns]

# %%
# 결측치 확인

total_df.isnull().sum()
# Out:
# 기준_년_코드                  0
# 기준_분기_코드                 0
# 상권_코드                    0
# 상권_코드_명                  0
# 서비스_업종_코드                0
#                     ...
# 연령대_30_매출_건수       1115448
# 연령대_40_매출_건수       1115448
# 연령대_50_매출_건수       1115448
# 연령대_60_이상_매출_건수    1115448
# 점포수                1115448
# Length: 85, dtype: int64

# %%
# total_df.to_csv('./통합_점포_추정매출.csv', encoding = 'cp949')

# %% [markdown]
# ## 2. 데이터 전처리
# ### (1) '명동거리' 상권 추출

# %%
total_df = pd.read_csv('C:/Users/Admin/Desktop/통합_점포_추정매출.csv', encoding = 'cp949')

# %%
# 점포-추정매출 통합 데이터 중 '명동거리'에 해당하는 상권만 추출
# '명동거리' 상권의 상권 코드 = 1001203

df_m = total_df[total_df['상권_코드'] == 1001203]

# %%
# 결과 확인

df_m.head()
# Out:
#       Unnamed: 0  기준_년_코드  기준_분기_코드    상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  \
# 222          222     2015         1  1001203    명동거리  CS300017      시계및귀금속
# 265          265     2015         1  1001203    명동거리  CS300009         청과상
# 2241        2241     2015         1  1001203    명동거리  CS300023        미용재료
# 4935        4935     2015         1  1001203    명동거리  CS200034          여관
# 6388        6388     2015         1  1001203    명동거리  CS300026          완구
#
#       점포_수  유사_업종_점포_수  개업_율  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 222     42          42     0  ...           6399.0   18228.0   40919.0
# 265      3           3    33  ...              0.0    1519.0    2407.0
# 2241     9           9    11  ...              NaN       NaN       NaN
# 4935     8           9     0  ...            742.0    2854.0    1735.0
# 6388     2           2     0  ...           6751.0   17036.0   27167.0
#
#       연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# 222         1734.0       36620.0       12246.0        4906.0        2964.0
# 265            0.0        1265.0        1681.0         861.0         121.0
# 2241           NaN           NaN           NaN           NaN           NaN
# 4935           0.0        2602.0        1053.0         603.0         253.0
# 6388        1812.0       19910.0        8944.0        7990.0        4266.0
#
#       연령대_60_이상_매출_건수   점포수
# 222             681.0  42.0
# 265               0.0   3.0
# 2241              NaN   NaN
# 4935             79.0   9.0
# 6388           1280.0   2.0
#
# [5 rows x 86 columns]

# %%
# 결과 확인

df_m.shape
# Out:
# (1881, 86)

# %% [markdown]
# ### (2)  '일반의류', '한식음식점' 업종 선택

# %%
cloth = df_m['서비스_업종_코드_명'] == '일반의류'
kfood = df_m['서비스_업종_코드_명'] == '한식음식점'

df_m_cloth = df_m[cloth].reset_index(drop = True)
df_m_kfood = df_m[kfood].reset_index(drop = True)

# %%
# 결과 확인
# '한식음식점'
# '한식음식점' 업종 코드 = CS100001

df_m_kfood.head()
# Out:
#    Unnamed: 0  기준_년_코드  기준_분기_코드    상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  \
# 0       42860     2015         1  1001203    명동거리  CS100001       한식음식점   175
# 1      108700     2015         2  1001203    명동거리  CS100001       한식음식점   170
# 2      195130     2015         3  1001203    명동거리  CS100001       한식음식점   168
# 3      293089     2015         4  1001203    명동거리  CS100001       한식음식점   170
# 4      391081     2016         1  1001203    명동거리  CS100001       한식음식점   176
#
#    유사_업종_점포_수  개업_율  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  \
# 0         211     3  ...          60940.0  258105.0  258474.0       10710.0
# 1         205     2  ...          59855.0  257359.0  267430.0       11073.0
# 2         202     3  ...          59725.0  271558.0  283035.0       12321.0
# 3         206     5  ...          68898.0  286213.0  286531.0       14800.0
# 4         215     8  ...          74110.0  301029.0  306635.0       13813.0
#
#    연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수  \
# 0      172366.0      142452.0       99767.0       59920.0          31382.0
# 1      173027.0      148498.0       99600.0       60127.0          32474.0
# 2      186568.0      150954.0      106829.0       63620.0          34301.0
# 3      188863.0      152950.0      111902.0       68185.0          36048.0
# 4      204240.0      160687.0      117693.0       71955.0          39296.0
#
#      점포수
# 0  210.0
# 1  206.0
# 2  202.0
# 3  206.0
# 4  210.0
#
# [5 rows x 86 columns]

# %%
a = df_m_kfood.iloc[20]
df_m_kfood = df_m_kfood.drop(20)
df_m_kfood = df_m_kfood.append(a)
df_m_kfood = df_m_kfood.reset_index(drop = True)
df_m_kfood
# Out:
#     Unnamed: 0  기준_년_코드  기준_분기_코드    상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  \
# 0        42860     2015         1  1001203    명동거리  CS100001       한식음식점
# 1       108700     2015         2  1001203    명동거리  CS100001       한식음식점
# 2       195130     2015         3  1001203    명동거리  CS100001       한식음식점
# 3       293089     2015         4  1001203    명동거리  CS100001       한식음식점
# 4       391081     2016         1  1001203    명동거리  CS100001       한식음식점
# 5       501774     2016         2  1001203    명동거리  CS100001       한식음식점
# 6       545375     2016         3  1001203    명동거리  CS100001       한식음식점
# 7       672595     2016         4  1001203    명동거리  CS100001       한식음식점
# 8       705465     2017         1  1001203    명동거리  CS100001       한식음식점
# 9       873607     2017         2  1001203    명동거리  CS100001       한식음식점
# 10      907130     2017         3  1001203    명동거리  CS100001       한식음식점
# 11     1002041     2017         4  1001203    명동거리  CS100001       한식음식점
# 12     1114730     2018         1  1001203    명동거리  CS100001       한식음식점
# 13     1154484     2018         2  1001203    명동거리  CS100001       한식음식점
# 14     1306752     2018         3  1001203    명동거리  CS100001       한식음식점
# 15     1369110     2018         4  1001203    명동거리  CS100001       한식음식점
# 16     1425720     2019         1  1001203    명동거리  CS100001       한식음식점
# 17     1511389     2019         2  1001203    명동거리  CS100001       한식음식점
# 5           41657.0  213.0
# 6           40392.0  207.0
# 7           43931.0  208.0
# 8           43269.0  207.0
# 9           45173.0  205.0
# 10          44616.0  206.0
# 11          44457.0  208.0
# 12          45747.0  205.0
# 13          48684.0  201.0
# 14          48075.0  198.0
# 15          68372.0  199.0
# 16          67256.0  199.0
# 17          66537.0  197.0
# 18          63665.0  193.0
# 19          60085.0  189.0
# 20          24571.0  190.0
# 21          21809.0  191.0
#
# [22 rows x 86 columns]

# %%
df_m_kfood['일반_점포_수'] = 0

for i in range(len(df_m_kfood)):
    n = df_m_kfood.loc[i, '점포_수']
    f = df_m_kfood.loc[i, '프랜차이즈_점포_수']
    df_m_kfood.loc[i,'일반_점포_수'] = n-f

# %%
# 연도, 분기 추출
year = list(df_m_kfood['기준_년_코드'])
month = list(df_m_kfood['기준_분기_코드'])

# (연도, 분기) list 생성
year_month = [i for i in zip(year,month)]
year_month

# '연도_분기' list 생성
# 1분기 = 3월 1일, 2분기 = 6월 1일, 3분기 = 9월 1일, 4분기 = 12월 1일
y_m = []
for i in range(len(year_month)):
    month = ''
    if int(year_month[i][1]) == 1:
        month = 3
    elif int(year_month[i][1]) == 2:
        month = 6
    elif int(year_month[i][1]) == 3:
        month = 9
    else :
        month = 12
    a = str(int(year_month[i][0])) + '-' + str(month) + '-1'
    y_m.append(a)
    
# 새로운 column 추가
df_date = df_m_kfood.copy()
df_date['Date'] = y_m
df_date['Date'] = df_date['Date'].astype('datetime64[ns]')
df_date = df_date.set_index('Date')
df_date
# Out:
#             Unnamed: 0  기준_년_코드  기준_분기_코드    상권_코드 상권_코드_명 서비스_업종_코드  \
# Date
# 2015-03-01       42860     2015         1  1001203    명동거리  CS100001
# 2015-06-01      108700     2015         2  1001203    명동거리  CS100001
# 2015-09-01      195130     2015         3  1001203    명동거리  CS100001
# 2015-12-01      293089     2015         4  1001203    명동거리  CS100001
# 2016-03-01      391081     2016         1  1001203    명동거리  CS100001
# 2016-06-01      501774     2016         2  1001203    명동거리  CS100001
# 2016-09-01      545375     2016         3  1001203    명동거리  CS100001
# 2016-12-01      672595     2016         4  1001203    명동거리  CS100001
# 2017-03-01      705465     2017         1  1001203    명동거리  CS100001
# 2017-06-01      873607     2017         2  1001203    명동거리  CS100001
# 2017-09-01      907130     2017         3  1001203    명동거리  CS100001
# 2017-12-01     1002041     2017         4  1001203    명동거리  CS100001
# 2018-03-01     1114730     2018         1  1001203    명동거리  CS100001
# 2018-06-01     1154484     2018         2  1001203    명동거리  CS100001
# 2018-09-01     1306752     2018         3  1001203    명동거리  CS100001
# 2018-12-01     1369110     2018         4  1001203    명동거리  CS100001
# 2019-03-01     1425720     2019         1  1001203    명동거리  CS100001
# 2019-06-01     1511389     2019         2  1001203    명동거리  CS100001
# 2019-09-01     1662181     2019         3  1001203    명동거리  CS100001
# 2019-12-01     1722741     2019         4  1001203    명동거리  CS100001
# 2020-03-01     1892749     2020         1  1001203    명동거리  CS100001
# 2020-06-01     1800371     2020         2  1001203    명동거리  CS100001
#
# 2015-09-01       63620.0          34301.0  202.0      134
# 2015-12-01       68185.0          36048.0  206.0      134
# 2016-03-01       71955.0          39296.0  210.0      137
# 2016-06-01       70127.0          41657.0  213.0      138
# 2016-09-01       68418.0          40392.0  207.0      138
# 2016-12-01       72647.0          43931.0  208.0      140
# 2017-03-01       66621.0          43269.0  207.0      139
# 2017-06-01       67141.0          45173.0  205.0      135
# 2017-09-01       68502.0          44616.0  206.0      137
# 2017-12-01       68510.0          44457.0  208.0      137
# 2018-03-01       64484.0          45747.0  205.0      133
# 2018-06-01       66025.0          48684.0  201.0      135
# 2018-09-01       64649.0          48075.0  198.0      135
# 2018-12-01       86964.0          68372.0  199.0      133
# 2019-03-01       82238.0          67256.0  199.0      131
# 2019-06-01       80011.0          66537.0  197.0      129
# 2019-09-01       78998.0          63665.0  193.0      126
# 2019-12-01       76639.0          60085.0  189.0      127
# 2020-03-01       39345.0          24571.0  190.0      126
# 2020-06-01       37490.0          21809.0  191.0      129
#
# [22 rows x 87 columns]

# %%
df_date.columns
# Out:
# Index(['Unnamed: 0', '기준_년_코드', '기준_분기_코드', '상권_코드', '상권_코드_명', '서비스_업종_코드',
#        '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률',
#        '폐업_점포_수', '프랜차이즈_점포_수', '당월_매출_금액', '당월_매출_건수', '주중_매출_비율', '주말_매출_비율',
#        '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율',
#        '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율', '시간대_06~11_매출_비율',
#        '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율',
#        '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율', '연령대_10_매출_비율',
#        '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율', '연령대_50_매출_비율',
#        '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액',
#        '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#        '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
#        '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
#        '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
#        '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
#        '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
#        '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수', '일반_점포_수'],
#       dtype='object')

# %%
df_date['당월_매출_금액']
# Out:
# Date
# 2015-03-01    1.880195e+10
# 2015-06-01    1.820813e+10
# 2015-09-01    1.831250e+10
# 2015-12-01    2.085848e+10
# 2016-03-01    2.166360e+10
# 2016-06-01    2.058392e+10
# 2016-09-01    2.020712e+10
# 2016-12-01    2.261717e+10
# 2017-03-01    1.992390e+10
# 2017-06-01    1.921238e+10
# 2017-09-01    1.958696e+10
# 2017-12-01    2.060235e+10
# 2018-03-01    1.829703e+10
# 2018-06-01    1.844875e+10
# 2018-09-01    1.792912e+10
# 2018-12-01    2.251798e+10
# 2019-03-01    1.827761e+10
# 2019-06-01    1.794264e+10
# 2019-09-01    1.771709e+10
# 2019-12-01    1.996679e+10
# 2020-03-01    1.016607e+10
# 2020-06-01    8.793477e+09
# Name: 당월_매출_금액, dtype: float64

# %%
a = df_date[df_date['기준_년_코드'] == 2020]
b = a[a['기준_분기_코드'] == 2]
t = b['점포_수']
m = b['일반_점포_수']
w = b['프랜차이즈_점포_수']

fig, ax = plt.subplots(figsize=(8,5))
sns.barplot(['총 점포 수', '일반 점포', '프랜차이즈 점포'], [t,m,w], ax = ax)
ax.set_title('"일반 의류" 점포 현황')

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("총 {:,d} 개".format(int(height)), (left+width/2, height*1.01), ha='center')

# %%
import numpy as np

a = df_date[df_date['기준_년_코드'] == 2020]
b = a[a['기준_분기_코드'] == 2]
c = b[['남성_매출_비율', '여성_매출_비율']]
aa = pd.DataFrame()

for col in c.columns:
    if int(c[col]) == 0:
        continue
    else:  
        n = int(c[col])
        word = col.split('_')[0]
        w_list = []
        w_list.append(word)
        ww = w_list*n
        aa = aa.append(ww)

fig, ax = plt.subplots(figsize=(5,5))
df = aa.loc[:,0].value_counts()


df.plot.pie(title = '남녀 매출 비율', autopct='%.1f%%')

# %%
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

a = df_date[df_date['기준_년_코드'] == 2020]
b = a[a['기준_분기_코드'] == 2]
c = b[['시간대_00~06_매출_비율', '시간대_06~11_매출_비율',
       '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율',
       '시간대_21~24_매출_비율']]

c['오전(0시 - 11시)'] = 0
c['오후(11시 - 17시)'] = 0
c['저녁(17시 - 24시)'] = 0

c['오전'] = float(c['시간대_00~06_매출_비율']) + float(c['시간대_06~11_매출_비율'])
c['오후'] = float(c['시간대_11~14_매출_비율']) + float(c['시간대_14~17_매출_비율'])
c['저녁'] = float(c['시간대_17~21_매출_비율']) + float(c['시간대_21~24_매출_비율'])

c = c.drop(['시간대_00~06_매출_비율', '시간대_06~11_매출_비율',
       '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율',
       '시간대_21~24_매출_비율'], axis = 1)

aa = pd.DataFrame()

for col in c.columns:
    if int(c[col]) == 0:
        continue
    else:  
        n = int(c[col])
        word = col
        w_list = []
        w_list.append(word)
        ww = w_list*n
        aa = aa.append(ww)

fig, ax = plt.subplots(figsize=(5,5))
df = aa.loc[:,0].value_counts()


df.plot.pie(title = '시간대별 매출 비율', autopct='%.1f%%')

# %%
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

a = df_date[df_date['기준_년_코드'] == 2020]
b = a[a['기준_분기_코드'] == 2]
c = b[['월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율',
       '토요일_매출_비율', '일요일_매출_비율']]


aa = pd.DataFrame()

for col in c.columns:
    if int(c[col]) == 0:
        continue
    else:  
        n = int(c[col])
        word = col.split('_')[0]
        w_list = []
        w_list.append(word)
        ww = w_list*n
        aa = aa.append(ww)

fig, ax = plt.subplots(figsize=(5,5))
df = aa.loc[:,0].value_counts()


df.plot.pie(title = '요일별 매출 비율', autopct='%.1f%%')

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.lineplot(x = df_date.index, y = df_date['당월_매출_금액'], ax = ax)
ax.set_title('"일반의류" 추정매출 변화')
ax.set_xlabel('연도')
ax.set_ylabel('추정매출 금액')
# Out:
# Text(0, 0.5, '추정매출 금액')

# %%
a = list(df_date.index)
a
# Out:
# [Timestamp('2015-03-01 00:00:00'),
#  Timestamp('2015-06-01 00:00:00'),
#  Timestamp('2015-09-01 00:00:00'),
#  Timestamp('2015-12-01 00:00:00'),
#  Timestamp('2016-03-01 00:00:00'),
#  Timestamp('2016-06-01 00:00:00'),
#  Timestamp('2016-09-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2017-03-01 00:00:00'),
#  Timestamp('2017-06-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-12-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-09-01 00:00:00'),
#  Timestamp('2019-12-01 00:00:00'),
#  Timestamp('2020-03-01 00:00:00'),
#  Timestamp('2020-06-01 00:00:00')]

# %%
# 결과 확인
# '한식음식점'

df_m_kfood.shape
# Out:
# (22, 85)

# %%
# column별 결측치 확인
# '한식음식점'

df_m_kfood.isnull().sum()
# Out:
# 기준_년_코드            0
# 기준_분기_코드           0
# 상권_코드              0
# 상권_코드_명            0
# 서비스_업종_코드          0
#                   ..
# 연령대_30_매출_건수       0
# 연령대_40_매출_건수       0
# 연령대_50_매출_건수       0
# 연령대_60_이상_매출_건수    0
# 점포수                0
# Length: 85, dtype: int64

# %%
# 전체 결측치 확인
# '한식음식점'

n_of_kfood = df_m_kfood.isnull().sum()
n_of_kfood.sum()
# Out:
# 0

# %%
# 결과 확인
# '일반의류'
# '일반의류' 업종 코드 = CS300011

df_m_cloth.head()
# Out:
#    기준_년_코드  기준_분기_코드    상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  유사_업종_점포_수  \
# 0     2015         1  1001203    명동거리  CS300011        일반의류   731         732
# 1     2015         2  1001203    명동거리  CS300011        일반의류   725         726
# 2     2015         3  1001203    명동거리  CS300011        일반의류   708         709
# 3     2015         4  1001203    명동거리  CS300011        일반의류   703         704
# 4     2016         1  1001203    명동거리  CS300011        일반의류   688         689
#
#    개업_율  개업_점포_수  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  \
# 0     1        9  ...        102759.00 280187.00 592586.00      50756.00
# 1     1        6  ...        125656.00 322910.00 695472.00      50686.00
# 2     1        7  ...        134950.00 354514.00 760756.00      62647.00
# 3     1        7  ...        105059.00 269793.00 567248.00      55122.00
# 4     1        7  ...         86663.00 227863.00 523951.00      44370.00
#
#    연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수  \
# 0     465099.00     165532.00     107597.00      70146.00         13654.00
# 1     534136.00     206561.00     128161.00      82228.00         16612.00
# 2     589233.00     211785.00     145112.00      88327.00         18170.00
# 3     431018.00     153923.00     115259.00      67505.00         14212.00
# 4     398173.00     139536.00      93570.00      62025.00         14140.00
#
#      점포수
# 0 733.00
# 1 728.00
# 2 715.00
# 3 706.00
# 4 689.00
#
# [5 rows x 85 columns]

# %%
# 결과 확인
# '일반의류'

df_m_cloth.shape
# Out:
# (22, 85)

# %%
# column별 결측치 확인
# '일반의류'

df_m_cloth.isnull().sum()
# Out:
# 기준_년_코드            0
# 기준_분기_코드           0
# 상권_코드              0
# 상권_코드_명            0
# 서비스_업종_코드          0
#                   ..
# 연령대_30_매출_건수       0
# 연령대_40_매출_건수       0
# 연령대_50_매출_건수       0
# 연령대_60_이상_매출_건수    0
# 점포수                0
# Length: 85, dtype: int64

# %%
# 전체 결측치 확인
# '일반의류'

n_of_cloth = df_m_cloth.isnull().sum()
n_of_cloth.sum()
# Out:
# 0

# %% [markdown]
# ### (3) 생존율 구하기

# %%
# 일반의류 업종 생존율 구하기 (생존율 = 1 - 개업률 + 폐업률)

new = df_m_cloth['개업_율']
fail = df_m_cloth['폐업_률']

survive = [100 - i + j for i,j in zip(new,fail)]
survive
# Out:
# [103,
#  101,
#  102,
#  101,
#  102,
#  100,
#  102,
#  100,
#  104,
#  102,
#  101,
#  101,
#  102,
#  100,
#  102,
#  101,
#  102,
#  102,
#  102,
#  100,
#  100,
#  102]

# %% [markdown]
# ### (4) 데이터 정규화

# %%
# 한식음식점 데이터 column

df_m_kfood.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명',
#        '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수',
#        '프랜차이즈_점포_수', '당월_매출_금액', '당월_매출_건수', '주중_매출_비율', '주말_매출_비율',
#        '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율',
#        '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율', '시간대_06~11_매출_비율',
#        '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율',
#        '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율', '연령대_10_매출_비율',
#        '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율', '연령대_50_매출_비율',
#        '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액',
#        '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#        '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
#        '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
#        '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
#        '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
#        '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
#        '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수'],
#       dtype='object')

# %%
# 불필요한 column 제거

useless = ['상권_코드', '상권_코드_명', '서비스_업종_코드_명', '점포수']

df_m_kfood = df_m_kfood.drop(useless, axis = 1)

len(df_m_kfood.columns)
# Out:
# 81

# %%
# Min-Max 정규화 진행

from sklearn import preprocessing

for i in range(3,81):
    if df_m_kfood.columns[i] == '폐업_률':
        continue
    else:
        x = df_m_kfood[df_m_kfood.columns[i]].values # Return numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(pd.DataFrame(x))
        # 적용
        df_m_kfood[df_m_kfood.columns[i]] = pd.DataFrame(x_scaled)ㅡ

# %%
# 일반의류 데이터 column

df_m_cloth.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명',
#        '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수',
#        '프랜차이즈_점포_수', '당월_매출_금액', '당월_매출_건수', '주중_매출_비율', '주말_매출_비율',
#        '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율',
#        '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율', '시간대_06~11_매출_비율',
#        '시간대_11~14_매출_비율', '시간대_14~17_매출_비율', '시간대_17~21_매출_비율',
#        '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율', '연령대_10_매출_비율',
#        '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율', '연령대_50_매출_비율',
#        '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액',
#        '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액',
#        '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
#        '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
#        '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
#        '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
#        '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
#        '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수'],
#       dtype='object')

# %%
# 불필요한 column 제거

useless = ['상권_코드', '상권_코드_명', '서비스_업종_코드_명', '점포수']

df_m_cloth = df_m_cloth.drop(useless, axis = 1)

len(df_m_cloth.columns)
# Out:
# 81

# %%
# Min-Max 정규화 진행

for i in range(3,81):
    if df_m_cloth.columns[i] == '폐업_률':
        continue
    else:
        x = df_m_cloth[df_m_cloth.columns[i]].values # Return numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(pd.DataFrame(x))
        # 적용
        df_m_cloth[df_m_cloth.columns[i]] = pd.DataFrame(x_scaled)

# %%
# 결과 확인
# 한식음식점

df_m_kfood
# Out:
#     기준_년_코드  기준_분기_코드 서비스_업종_코드  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  \
# 0      2015         1  CS100001  0.94        0.85  0.29     0.25     3
# 1      2015         2  CS100001  0.67        0.62  0.14     0.19     5
# 2      2015         3  CS100001  0.56        0.50  0.29     0.19     4
# 3      2015         4  CS100001  0.67        0.65  0.57     0.50     3
# 4      2016         1  CS100001  1.00        1.00  1.00     1.00     4
# 5      2016         2  CS100001  0.94        0.88  0.43     0.38     5
# 6      2016         3  CS100001  0.72        0.58  0.29     0.19     6
# 7      2016         4  CS100001  0.89        0.73  0.43     0.38     2
# 8      2017         1  CS100001  0.83        0.69  0.14     0.12     2
# 9      2017         2  CS100001  0.67        0.62  0.29     0.25     4
# 10     2017         3  CS100001  0.78        0.69  0.43     0.44     3
# 11     2017         4  CS100001  0.78        0.69  0.43     0.38     4
# 12     2018         1  CS100001  0.61        0.62  0.14     0.06     2
# 13     2018         2  CS100001  0.50        0.38  0.29     0.19     6
# 14     2018         3  CS100001  0.50        0.38  0.14     0.12     2
# 15     2018         4  CS100001  0.44        0.38  0.14     0.12     2
# 16     2019         1  CS100001  0.33        0.31  0.29     0.19     4
# 17     2019         2  CS100001  0.22        0.23  0.29     0.19     4
# 18     2019         3  CS100001  0.11        0.19  0.14     0.12     3
# 19     2019         4  CS100001  0.00        0.00  0.29     0.25     4
# 20     2020         2  CS100001  0.06        0.00  0.43     0.38     6
# 21     2020         1  CS100001  0.00        0.04  0.00     0.00     0
#
#     폐업_점포_수  프랜차이즈_점포_수  ...  시간대_건수~21_매출_건수  시간대_건수~24_매출_건수  남성_매출_건수  \
# 0      0.46        0.67  ...             0.82             0.76      0.66
# 1      0.85        0.56  ...             0.77             0.74      0.65
# 2      0.62        0.44  ...             0.85             0.74      0.73
# 3      0.46        0.67  ...             0.91             0.90      0.82
# 4      0.69        1.00  ...             1.00             1.00      0.91
# 5      0.85        0.78  ...             0.89             0.92      0.80
# 6      1.00        0.33  ...             0.84             0.80      0.75
# 7      0.31        0.44  ...             0.94             0.99      0.90
# 8      0.38        0.44  ...             0.79             0.79      0.77
# 9      0.62        0.56  ...             0.78             0.74      0.75
# 10     0.54        0.56  ...             0.79             0.72      0.76
# 11     0.62        0.56  ...             0.78             0.75      0.73
# 12     0.38        0.67  ...             0.63             0.62      0.58
# 13     0.85        0.22  ...             0.60             0.65      0.59
# 14     0.31        0.22  ...             0.64             0.56      0.61
# 15     0.31        0.33  ...             0.99             0.73      1.00
# 16     0.54        0.33  ...             0.74             0.47      0.82
# 17     0.54        0.33  ...             0.70             0.43      0.80
# 18     0.38        0.44  ...             0.70             0.40      0.78
# 19     0.54        0.11  ...             0.72             0.53      0.82
# 20     0.85        0.00  ...             0.00             0.00      0.00
# 21     0.00        0.22  ...             0.07             0.09      0.07
#
#     여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
#