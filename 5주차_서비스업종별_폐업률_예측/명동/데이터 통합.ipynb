# %% [markdown]
# # 상권 - 서비스 업종 추정매출, 폐업률

# %%
import pandas as pd

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### (1) 업종별 점포 데이터

# %%
# 2020년 = service_info_2020, 
# 2019년 = service_info_2019, 
# .... 
# 2015년 = service_info_2015

for i in range(2015, 2021):
    globals()['service_info_{}'.format(i)] = pd.read_csv(path + str(i) + '.csv', encoding = 'cp949')

# %%
# 확인

service_info_2020.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300042
# 2     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300041
# 3     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300040
# 4     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300038
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0      전자상거래업     8           8     0        0     0        0           0
# 1         주유소     1           1     0        0     0        0           0
# 2         예술품     9           9     0        0     0        0           0
# 3    재생용품 판매점     0           0     0        0     0        0           0
# 4       자동차부품    10          10     0        0     0        0           0

# %%
food = ['한식음식점', '중식음식점', '일식음식점', '양식음식점', '제과점', '패스트푸드점', '치킨전문점', '분식전문점', '호프-간이주점',
       '커피-음료']

service = ['일반교습학원', '외국어학원', '예술학원', '컴퓨터학원', '스포츠 강습', '일반의원', '치과의원', '한의원', '동물병원',
          '변호사사무소', '변리사사무소', '법무사사무소', '기타법무서비스', '회계사사무소', '세무사사무소', '당구장',
          '골프연습장', '볼링장', 'PC방', '전자게임장', '기타오락장', '복권방', '통신기기수리', '스포츠클럽', '자동차수리', '자동차미용',
          '모터사이클수리', '미용실', '네일숍', '피부관리실', '세탁소', '가전제품수리', '부동산중개업', '여관', '게스트하우스', '고시원',
          '노래방', '독서실', 'DVD방', '녹음실', '사진관', '통번역서비스', '건축물청소', '여행사', '비디오/서적임대', '의류임대', 
          '가정용품임대']

retail = ['슈퍼마켓', '편의점', '컴퓨터및주변장치판매', '핸드폰', '주류도매', '미곡판매', '육류판매', '수산물판매', '청과상',
          '반찬가게', '일반의류', '한복점', '유아의류', '신발', '가방', '안경', '시계및귀금속', '의약품', '의료기기', '서적', 
         '문구', '화장품', '미용재료', '운동/경기용품', '자전거 및 기타운송장비', '완구', '섬유제품', '화초', '애완동물', '중고가구', 
         '가구', '가전제품', '철물점', '악기', '인테리어', '조명용품', '중고차판매', '자동차부품', '모터사이클및부품', 
          '재생용품 판매점', '예술품', '주유소', '전자상거래업']

# %%
food_code = []
service_code = []
retail_code = []

food_name = []
service_name = []
retail_name = []

# %%
for i in service_info_2020.index:
    r = service_info_2020.loc[i,'서비스_업종_코드_명']
    if r in food:
        food_code.append(service_info_2020.loc[i,'서비스_업종_코드'])
        food_name.append(service_info_2020.loc[i,'서비스_업종_코드_명'])
    if r in service:
        service_code.append(service_info_2020.loc[i,'서비스_업종_코드'])
        service_name.append(service_info_2020.loc[i,'서비스_업종_코드_명'])
    if r in retail:
        retail_code.append(service_info_2020.loc[i,'서비스_업종_코드'])
        retail_name.append(service_info_2020.loc[i,'서비스_업종_코드_명'])

# %%
df1 = pd.DataFrame({'code' : food_code, 'name' : food_name})

# %%
df1['code'].unique()
# Out:
# array(['CS100010', 'CS100009', 'CS100008', 'CS100007', 'CS100006',
#        'CS100005', 'CS100004', 'CS100003', 'CS100002', 'CS100001'],
#       dtype=object)

# %%
df1['name'].unique()
# Out:
# array(['커피-음료', '호프-간이주점', '분식전문점', '치킨전문점', '패스트푸드점', '제과점', '양식음식점',
#        '일식음식점', '중식음식점', '한식음식점'], dtype=object)

# %%
print("food : {}\nservice : {}\nretail : {}".format(len(food), len(service), len(retail)))
# Out:
# food : 10
# service : 47
# retail : 43

# %%
food_df = pd.DataFrame()
service_df = pd.DataFrame()
retail_df = pd.DataFrame()

for f in food:
    food_df = food_df.append(service_info_2020[service_info_2020['서비스_업종_코드_명'] == f])
for s in service:
    service_df = service_df.append(service_info_2020[service_info_2020['서비스_업종_코드_명'] == s])
for r in retail:
    retail_df = retail_df.append(service_info_2020[service_info_2020['서비스_업종_코드_명'] == r])

# %%
len(food_df['서비스_업종_코드_명'].unique())
# Out:
# 10

# %%
len(service_df['서비스_업종_코드_명'].unique())
# Out:
# 47

# %%
len(retail_df['서비스_업종_코드_명'].unique())
# Out:
# 43

# %%
len(a)
# Out:
# 5

# %%
service_df['서비스_업종_코드_명'].unique()
# Out:
# array(['일반교습학원', '외국어학원', '예술학원', '컴퓨터학원', '스포츠 강습', '일반의원', '치과의원',
#        '한의원', '동물병원', '변호사사무소', '변리사사무소', '법무사사무소', '기타법무서비스', '회계사사무소',
#        '세무사사무소', '당구장', '골프연습장', '볼링장', 'PC방', '전자게임장', '기타오락장', '복권방',
#        '통신기기수리', '스포츠클럽', '자동차수리', '자동차미용', '모터사이클수리', '미용실', '네일숍',
#        '피부관리실', '세탁소', '가전제품수리', '부동산중개업', '여관', '게스트하우스', '고시원', '노래방',
#        '독서실', 'DVD방', '녹음실', '사진관', '통번역서비스', '건축물청소', '여행사', '비디오/서적임대',
#        '의류임대', '가정용품임대'], dtype=object)

# %%
retail_df['서비스_업종_코드_명'].unique()
# Out:
# array(['슈퍼마켓', '편의점', '컴퓨터및주변장치판매', '핸드폰', '주류도매', '미곡판매', '육류판매',
#        '수산물판매', '청과상', '반찬가게', '일반의류', '한복점', '유아의류', '신발', '가방', '안경',
#        '시계및귀금속', '의약품', '의료기기', '서적', '문구', '화장품', '미용재료', '운동/경기용품',
#        '완구', '섬유제품', '화초', '애완동물', '중고가구', '가구', '가전제품', '철물점', '악기',
#        '인테리어', '조명용품', '중고차판매', '자동차부품', '모터사이클및부품', '재생용품 판매점', '예술품',
#        '주유소', '전자상거래업'], dtype=object)

# %%
service_info_2020.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')

# %%
service_info_2019.shape
# Out:
# (365030, 15)

# %%
for i in range(2015, 2021):
    dfff = globals()['service_info_{}'.format(i)]
    dlist = []
    for j in dfff.index:
        if (dfff.loc[j,'점포_수'] == 0) and (dfff.loc[j,'유사_업종_점포_수'] == 0) and (dfff.loc[j,'개업_율'] == 0) \
        and (dfff.loc[j,'개업_점포_수'] == 0) and (dfff.loc[j,'폐업_률'] == 0) and (dfff.loc[j,'폐업_점포_수'] == 0) and \
        (dfff.loc[j,'프랜차이즈_점포_수'] == 0):
            dlist.append(j)
    globals()['service_info_{}'.format(i)] = globals()['service_info_{}'.format(i)].drop(dlist).reset_index(drop = True)

# %%
service_info_2019.shape
# Out:
# (272050, 15)

# %%
for i in range(2015, 2021):
    df = globals()['service_info_{}'.format(i)]
    for j in range(1, 5):
        df_2 = df[df['기준_분기_코드'] == j]
        for k in mlist:
            df_3 = df_2[df_2['상권_코드'] == k]
            globals()['set_{}_{}_{}'.format(i, j, k)] = set(list(df_3['서비스_업종_코드'].unique()))
        if j == 2 and i == 2020:
            break

# %%
mlist = [i for i in range(1000001, 1001497)]
len(mlist)
# Out:
# 1496

# %%
for i in mlist:
    globals()['market_{}'.format(i)] = []

# %%
all_service = set(service_info_2020['서비스_업종_코드'].unique())



for service in all_service:
    for i in mlist:
        if (service in globals()['set_2020_2_{}'.format(i)]) and (service in globals()['set_2020_1_{}'.format(i)]) and \
        (service in globals()['set_2019_4_{}'.format(i)]) and (service in globals()['set_2019_3_{}'.format(i)]) and \
        (service in globals()['set_2019_2_{}'.format(i)]) and (service in globals()['set_2019_1_{}'.format(i)]) and \
        (service in globals()['set_2018_4_{}'.format(i)]) and (service in globals()['set_2018_3_{}'.format(i)]) and \
        (service in globals()['set_2018_2_{}'.format(i)]) and (service in globals()['set_2018_1_{}'.format(i)]) and \
        (service in globals()['set_2017_4_{}'.format(i)]) and (service in globals()['set_2017_3_{}'.format(i)]) and \
        (service in globals()['set_2017_2_{}'.format(i)]) and (service in globals()['set_2017_1_{}'.format(i)]) and \
        (service in globals()['set_2016_4_{}'.format(i)]) and (service in globals()['set_2016_3_{}'.format(i)]) and \
        (service in globals()['set_2016_2_{}'.format(i)]) and (service in globals()['set_2016_1_{}'.format(i)]) and \
        (service in globals()['set_2015_4_{}'.format(i)]) and (service in globals()['set_2015_3_{}'.format(i)]) and \
        (service in globals()['set_2015_2_{}'.format(i)]) and (service in globals()['set_2015_1_{}'.format(i)]):
            globals()['market_{}'.format(i)].append(service)
        else:
            continue

# %%
for i in mlist:
    n = len(globals()['market_{}'.format(i)])
    print("{} : {}, {}".format(i ,n, type(globals()['market_{}'.format(i)])))
# Out:
# 1000001 : 41, <class 'list'>
# 1000002 : 27, <class 'list'>
# 1000003 : 56, <class 'list'>
# 1000004 : 22, <class 'list'>
# 1000005 : 26, <class 'list'>
# 1000006 : 25, <class 'list'>
# 1000007 : 32, <class 'list'>
# 1000008 : 20, <class 'list'>
# 1000009 : 23, <class 'list'>
# 1000010 : 33, <class 'list'>
# 1000011 : 40, <class 'list'>
# 1000012 : 25, <class 'list'>
# 1000013 : 29, <class 'list'>
# 1000014 : 19, <class 'list'>
# 1000015 : 40, <class 'list'>
# 1000016 : 41, <class 'list'>
# 1000017 : 39, <class 'list'>
# 1000018 : 35, <class 'list'>
# 1000019 : 37, <class 'list'>
# 1000020 : 39, <class 'list'>
# 1000021 : 31, <class 'list'>
# 1000022 : 29, <class 'list'>
# 1000023 : 25, <class 'list'>
# 1000024 : 16, <class 'list'>
# 1000025 : 16, <class 'list'>
# 1000026 : 27, <class 'list'>
# 1000027 : 20, <class 'list'>
# 1000028 : 51, <class 'list'>
# 1000029 : 18, <class 'list'>
# 1000030 : 39, <class 'list'>
# 1000031 : 32, <class 'list'>
# 1000032 : 54, <class 'list'>
# ...

# %%
df_2020 = service_info_2020[service_info_2020['상권_코드'] == 1000013]
df_2018 = service_info_2018[service_info_2018['상권_코드'] == 1000013]

n1 = len(df_2020['서비스_업종_코드'].unique())
n2 = len(df_2018['서비스_업종_코드'].unique())

print(n1,n2)
# Out:
# 29 29

# %%
# 2020
list_2020 = []
for m in mlist:
    df = service_info_2020[service_info_2020['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2020.append(j)

service_info_2020 = service_info_2020.drop(list_2020).reset_index(drop = True)

# %%
# 2019
list_2019 = []
for m in mlist:
    df = service_info_2019[service_info_2019['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2019.append(j)

service_info_2019 = service_info_2019.drop(list_2019).reset_index(drop = True)

# %%
# 2018
list_2018 = []
for m in mlist:
    df = service_info_2018[service_info_2018['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2018.append(j)

service_info_2018 = service_info_2018.drop(list_2018).reset_index(drop = True)

# %%
# 2017
list_2017 = []
for m in mlist:
    df = service_info_2017[service_info_2017['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2017.append(j)

service_info_2017 = service_info_2017.drop(list_2017).reset_index(drop = True)

# %%
# 2016
list_2016 = []
for m in mlist:
    df = service_info_2016[service_info_2016['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2016.append(j)
            
service_info_2016 = service_info_2016.drop(list_2016).reset_index(drop = True)

# %%
# 2015
list_2015 = []
for m in mlist:
    df = service_info_2015[service_info_2015['상권_코드'] == m]
    for j in df.index:
        if df.loc[j,'서비스_업종_코드'] in globals()['market_{}'.format(m)]:
            continue
        else:
            list_2015.append(j)
            
service_info_2015 = service_info_2015.drop(list_2015).reset_index(drop = True)

# %%
df_2020 = service_info_2020[service_info_2020['상권_코드'] == 1000013]
df_2018 = service_info_2016[service_info_2016['상권_코드'] == 1000013]

n1 = len(df_2020['서비스_업종_코드'].unique())
n2 = len(df_2018['서비스_업종_코드'].unique())

print(n1,n2)
# Out:
# 29 29

# %% [markdown]
# ### (2) 업종별 추정매출 데이터

# %%
# 2020년 = service_sales_2020, 
# 2019년 = service_sales_2019, 
# .... 
# 2015년 = service_sales_2015

for i in range(2015, 2021):
    globals()['service_sales_{}'.format(i)] = pd.read_csv(path + str(i) + '.csv', encoding = 'cp949')

# %%
# 확인

service_sales_2020
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0         2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1         2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 2         2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 3         2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# 4         2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300027
# ...        ...       ...      ...        ...      ...          ...       ...
# 66506     2020         1        A       골목상권  1000001          계동길  CS100005
# 66507     2020         1        A       골목상권  1000001          계동길  CS100004
# 66508     2020         1        A       골목상권  1000001          계동길  CS100003
# 66509     2020         1        A       골목상권  1000001          계동길  CS100002
# 66510     2020         1        A       골목상권  1000001          계동길  CS100001
#
# ...

# %%
# 분기 분리

for i in range(2015, 2021):
    df = globals()['service_sales_{}'.format(i)]
    for j in range(1, 5):
        df_2 = df[df['기준_분기_코드'] == j]
        n1 = len(df_2['상권_코드'].unique())
        print("{}_{} : {}".format(i, j, n1))
        if i == 2020 and j == 2:
            break
# Out:
# 2015_1 : 1491
# 2015_2 : 1491
# 2015_3 : 1491
# 2015_4 : 1491
# 2016_1 : 1492
# 2016_2 : 1493
# 2016_3 : 1493
# 2016_4 : 1491
# 2017_1 : 1492
# 2017_2 : 1492
# 2017_3 : 1491
# 2017_4 : 1491
# 2018_1 : 1490
# 2018_2 : 1490
# 2018_3 : 1491
# 2018_4 : 1491
# 2019_1 : 1487
# 2019_2 : 1485
# 2019_3 : 1486
# 2019_4 : 1487
# 2020_1 : 1485
# 2020_2 : 1485

# %%
# 2015 ~ 2020 추정매출, 폐업률 수직 통합

total_service_info = pd.DataFrame()
total_service_sales = pd.DataFrame()

# 점포 데이터 통합 (2015 ~ 2020)
for i in range (2015, 2021):
    total_service_info = total_service_info.append(globals()['service_info_{}'.format(i)], ignore_index = True)

# 불필요한 column 제거
total_service_info = total_service_info.drop(['상권_구분_코드', '상권_구분_코드_명', '서비스_업종_코드_명'], axis=1)

# 추정매출 데이터 통합 (2015 ~ 2020)
for i in range (2015, 2021):
    total_service_sales = total_service_sales.append(globals()['service_sales_{}'.format(i)], ignore_index = True)

# 불필요한 column 제거
total_service_sales = total_service_sales.drop(['상권_구분_코드', '상권_구분_코드_명', '서비스_업종_코드_명'], axis=1)

# %%
# 결과 확인
# 통합 점포 데이터

total_service_info
# Out:
#          기준_년_코드  기준_분기_코드    상권_코드       상권_코드_명 서비스_업종_코드  점포_수  유사_업종_점포_수  \
# 0           2015         1  1001490       길동복조리시장  CS300011    33          33
# 1           2015         1  1001046  서울 관악구 신림역_4  CS300001    18          18
# 2           2015         1  1000609        개봉로11길  CS100001     9           9
# 3           2015         1  1000910       도산대로81길  CS100004     9           9
# 4           2015         1  1000862        방배로18길  CS100002     1           2
# ...          ...       ...      ...           ...       ...   ...         ...
# 1259011     2020         1  1000001           계동길  CS100005     2           4
# 1259012     2020         1  1000001           계동길  CS100004     3           3
# 1259013     2020         1  1000001           계동길  CS100003     3           3
# 1259014     2020         1  1000001           계동길  CS100002     0           1
# 1259015     2020         1  1000001           계동길  CS100001    19          19
#
# ...

# %%
total_service_info.isnull().sum()
# Out:
# 기준_년_코드       0
# 기준_분기_코드      0
# 상권_코드         0
# 상권_코드_명       0
# 서비스_업종_코드     0
# 점포_수          0
# 유사_업종_점포_수    0
# 개업_율          0
# 개업_점포_수       0
# 폐업_률          0
# 폐업_점포_수       0
# 프랜차이즈_점포_수    0
# dtype: int64

# %%
# 결과 확인
# 통합 추정매출 데이터

total_service_sales
# Out:
#         기준_년_코드  기준_분기_코드    상권_코드  상권_코드_명 서비스_업종_코드    당월_매출_금액  당월_매출_건수  \
# 0          2015         1  1001018  포이사거리_2  CS300021  3390014653     88106
# 1          2015         1  1000481  성미산로11길  CS300011   477810637      1339
# 2          2015         1  1000440   세검정로1길  CS200008    29303647       582
# 3          2015         1  1001458     인헌시장  CS100005   312469941     38207
# 4          2015         1  1000756    사당로8길  CS200016    38474191      2583
# ...         ...       ...      ...      ...       ...         ...       ...
# 862311     2020         1  1000001      계동길  CS100005   257814129     27092
# 862312     2020         1  1000001      계동길  CS100004   156728306      3589
# 862313     2020         1  1000001      계동길  CS100003    55484866      1272
# 862314     2020         1  1000001      계동길  CS100002    25767161      1413
# 862315     2020         1  1000001      계동길  CS100001   431442455     18548
#
# ...

# %%
# 공통되는 column 찾기

c_info = set(total_service_info.columns)
c_sales = set(total_service_sales.columns)
c_same = list(set.intersection(c_info, c_sales))

c_same
# Out:
# ['상권_코드', '기준_분기_코드', '상권_코드_명', '서비스_업종_코드', '기준_년_코드']

# %%
# 통합 점포 데이터 + 통합 추정매출 데이터 = total_df

total_df = pd.merge(total_service_info, total_service_sales, how = 'left', on = c_same)

# %%
# 결과 확인
# 전체 통합 데이터

total_df
# Out:
#          기준_년_코드  기준_분기_코드    상권_코드       상권_코드_명 서비스_업종_코드  점포_수  유사_업종_점포_수  \
# 0           2015         1  1001490       길동복조리시장  CS300011    33          33
# 1           2015         1  1001046  서울 관악구 신림역_4  CS300001    18          18
# 2           2015         1  1000609        개봉로11길  CS100001     9           9
# 3           2015         1  1000910       도산대로81길  CS100004     9           9
# 4           2015         1  1000862        방배로18길  CS100002     1           2
# ...          ...       ...      ...           ...       ...   ...         ...
# 1259011     2020         1  1000001           계동길  CS100005     2           4
# 1259012     2020         1  1000001           계동길  CS100004     3           3
# 1259013     2020         1  1000001           계동길  CS100003     3           3
# 1259014     2020         1  1000001           계동길  CS100002     0           1
# 1259015     2020         1  1000001           계동길  CS100001    19          19
#
# ...

# %% [markdown]
# ## 3. 결측치 확인
# ### (1) 각 연도, 분기 데이터에 1496개 상권이 모두 포함되어 있는지 확인

# %%
# 연도 분리
for i in range(2015, 2021):
    globals()['df_{}'.format(i)] = total_df[total_df['기준_년_코드'] == i]
    
# 분기 분리
for i in range(2015, 2021):
    for j in range(1, 5):
        globals()['df_{}_{}'.format(i, j)] = globals()['df_{}'.format(i)][globals()['df_{}'.format(i)]['기준_분기_코드'] == j]
        if i == 2020 and j == 2:
            break

# %%
# 연도별, 분기별 상권 개수 출력

df_list = [df_2020_1, df_2020_2, df_2019_1, df_2019_2, df_2019_3, df_2019_4, df_2018_1, df_2018_2, df_2018_3, df_2018_4, df_2017_1, 
        df_2017_2, df_2017_3, df_2017_4, df_2016_1, df_2016_2, df_2016_3, df_2016_4, df_2015_1, df_2015_2, df_2015_3, df_2015_4]

for df in df_list:
    print(len(df['상권_코드'].unique()))
# Out:
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496
# 1496

# %% [markdown]
# ## (2) column별 결측치 확인

# %%
# 모든 column name

total_df.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_코드', '상권_코드_명', '서비스_업종_코드', '점포_수',
#        '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수',
#        '당월_매출_금액', '당월_매출_건수', '주중_매출_비율', '주말_매출_비율', '월요일_매출_비율',
#        '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율', '토요일_매출_비율',
#        '일요일_매출_비율', '시간대_00~06_매출_비율', '시간대_06~11_매출_비율', '시간대_11~14_매출_비율',
#        '시간대_14~17_매출_비율', '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율',
#        '여성_매출_비율', '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율',
#        '연령대_40_매출_비율', '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액',
#        '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액',
#        '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액', '시간대_00~06_매출_금액',
#        '시간대_06~11_매출_금액', '시간대_11~14_매출_금액', '시간대_14~17_매출_금액',
#        '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액',
#        '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
# ...

# %%
# 모든 84개 열에 대한 각각의 결측치 수

for column in total_df.columns:
    n_of_null = total_df[column].isnull().sum()
    print("{} : {}".format(column, n_of_null))
# Out:
# 기준_년_코드 : 0
# 기준_분기_코드 : 0
# 상권_코드 : 0
# 상권_코드_명 : 0
# 서비스_업종_코드 : 0
# 점포_수 : 0
# 유사_업종_점포_수 : 0
# 개업_율 : 0
# 개업_점포_수 : 0
# 폐업_률 : 0
# 폐업_점포_수 : 0
# 프랜차이즈_점포_수 : 0
# 당월_매출_금액 : 483875
# 당월_매출_건수 : 483875
# 주중_매출_비율 : 483875
# 주말_매출_비율 : 483875
# 월요일_매출_비율 : 483875
# 화요일_매출_비율 : 483875
# 수요일_매출_비율 : 483875
# 목요일_매출_비율 : 483875
# 금요일_매출_비율 : 483875
# 토요일_매출_비율 : 483875
# 일요일_매출_비율 : 483875
# 시간대_00~06_매출_비율 : 483875
# 시간대_06~11_매출_비율 : 483875
# 시간대_11~14_매출_비율 : 483875
# 시간대_14~17_매출_비율 : 483875
# 시간대_17~21_매출_비율 : 483875
# 시간대_21~24_매출_비율 : 483875
# 남성_매출_비율 : 483875
# 여성_매출_비율 : 483875
# 연령대_10_매출_비율 : 483875
# 연령대_20_매출_비율 : 483875
# 연령대_30_매출_비율 : 483875
# 연령대_40_매출_비율 : 483875
# 연령대_50_매출_비율 : 483875
# 연령대_60_이상_매출_비율 : 483875
# 주중_매출_금액 : 483875
# 주말_매출_금액 : 483875
# 월요일_매출_금액 : 483875
# 화요일_매출_금액 : 483875
# 수요일_매출_금액 : 483875
# 목요일_매출_금액 : 483875
# 금요일_매출_금액 : 483875
# 토요일_매출_금액 : 483875
# 일요일_매출_금액 : 483875
# 시간대_00~06_매출_금액 : 483875
# 시간대_06~11_매출_금액 : 483875
# ...

# %%
total_df.shape
# Out:
# (1259016, 84)
